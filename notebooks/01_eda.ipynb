# %% [markdown]
# # Initial Data Exploration
# This notebook contains initial data exploration and analysis.

# %%
import pandas as pd
import json

def parse_youtube_history(json_file):
    # Read the JSON file
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    # If the data is a list of records
    if isinstance(data, list):
        records = data
    else:
        # If it's a single record, wrap it in a list
        records = [data]
    
    # Process each record to flatten the data
    processed_records = []
    for record in records:
        processed_record = {
            'header': record.get('header'),
            'title': record.get('title'),
            'title_url': record.get('titleUrl'),
            'channel_name': record['subtitles'][0]['name'] if record.get('subtitles') else None,
            'channel_url': record['subtitles'][0]['url'] if record.get('subtitles') else None,
            'timestamp': pd.to_datetime(record.get('time')),
            'products': ', '.join(record.get('products', [])),
            'activity_controls': ', '.join(record.get('activityControls', []))
        }
        processed_records.append(processed_record)
    
    # Create DataFrame
    df = pd.DataFrame(processed_records)
    return df

# Usage example
if __name__ == "__main__":
    # Replace 'your_file.json' with your actual JSON file path
    file_path = '/Users/karthiknadella/Documents/Data Stories/youtube/data/raw/watch-history.json'
    try:
        df = parse_youtube_history(file_path)
        print("DataFrame created successfully!")
        print("\nDataFrame Info:")
        print(df.info())
        print("\nFirst few rows:")
        print(df.head())
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# DataFrame created successfully!
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5867 entries, 0 to 5866
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   header             5867 non-null   object
#  1   title              5867 non-null   object
#  2   title_url          5867 non-null   object
#  3   channel_name       5781 non-null   object
#  4   channel_url        5781 non-null   object
#  5   timestamp          5867 non-null   datetime64[ns, UTC]
#  6   products           5867 non-null   object
#  7   activity_controls  5867 non-null   object
# dtypes: datetime64[ns, UTC](1), object(7)
# memory usage: 366.8+ KB
# None
#
# First few rows:
#     header                                              title  \
# 0  YouTube  Watched Taylor Swift and Travis Kelce partying...
# 1  YouTube     Watched That RARE Moment ERNIE Johnson SNAPPED
# 2  YouTube  Watched 12 Min Full Body Fat Burn Cardio Worko...
# 3  YouTube  Watched 20 Min Full Body Gentle Barre Workout,...
# 4  YouTube  Watched Forget the Draymond Green Show, we Wan...
#
#                                      title_url       channel_name  \
# 0  https://www.youtube.com/watch?v=Gp4KQ0yEzoo  Swiftly Explained
# 1  https://www.youtube.com/watch?v=beq305XH714          HoopLists
# 2  https://www.youtube.com/watch?v=IY3dD2vQYtw   Action Jacquelyn
# 3  https://www.youtube.com/watch?v=zibBK8tvaaE   Action Jacquelyn
# 4  https://www.youtube.com/watch?v=zjanzaY2jtM              heavy
#
#                                          channel_url  \
# 0  https://www.youtube.com/channel/UCKTZ2MmK0_9hZ...
# 1  https://www.youtube.com/channel/UCZBaWSQCEd3mb...
# 2  https://www.youtube.com/channel/UCezEzIGp34wPB...
# 3  https://www.youtube.com/channel/UCezEzIGp34wPB...
# 4  https://www.youtube.com/channel/UCDH6W-YM39hL0...
#
#                          timestamp products      activity_controls
# 0 2024-11-17 21:43:04.210000+00:00  YouTube  YouTube watch history
# 1 2024-11-17 21:42:55.602000+00:00  YouTube  YouTube watch history
# 2 2024-11-15 13:38:03.575000+00:00  YouTube  YouTube watch history
# 3 2024-11-15 13:37:24.315000+00:00  YouTube  YouTube watch history
# 4 2024-11-14 21:21:43.623000+00:00  YouTube  YouTube watch history

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

def create_youtube_timeseries(json_file):
    # Read and parse the JSON file
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    # Ensure data is a list
    records = data if isinstance(data, list) else [data]
    
    # Create DataFrame
    df = pd.DataFrame(records)
    
    # Convert time to datetime
    df['time'] = pd.to_datetime(df['time'])
    
    # Set time as index and resample by day to get daily counts
    daily_counts = df.set_index('time').resample('D').size().reset_index()
    daily_counts.columns = ['date', 'video_count']
    
    # Create the visualization
    plt.figure(figsize=(12, 6))
    sns.set_style("whitegrid")
    
    # Plot the data
    plt.plot(daily_counts['date'], daily_counts['video_count'], 
             color='#4A90E2', linewidth=2)
    
    # Customize the plot
    plt.title('YouTube Videos Watched Over Time', pad=20, size=14)
    plt.xlabel('Date', labelpad=10)
    plt.ylabel('Number of Videos', labelpad=10)
    
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45)
    
    # Adjust layout to prevent label cutoff
    plt.tight_layout()
    
    # Add some statistics as text
    total_videos = daily_counts['video_count'].sum()
    avg_daily = daily_counts['video_count'].mean()
    max_daily = daily_counts['video_count'].max()
    
    stats_text = f'Total Videos: {int(total_videos)}\n'
    stats_text += f'Avg Daily: {avg_daily:.1f}\n'
    stats_text += f'Max Daily: {int(max_daily)}'
    
    plt.text(0.02, 0.98, stats_text,
             transform=plt.gca().transAxes,
             verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    return plt

# Usage example
if __name__ == "__main__":
    # Replace with your JSON file path
    file_path = '/Users/karthiknadella/Documents/Data Stories/youtube/data/raw/watch-history.json'
    try:
        plt = create_youtube_timeseries(file_path)
        plt.show()
        
        # Optionally save the plot
        # plt.savefig('youtube_history_plot.png', dpi=300, bbox_inches='tight')
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# %%
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Get API key from environment
api_key = os.getenv('YOUTUBE_API_KEY')
if not api_key:
    raise ValueError("Missing YOUTUBE_API_KEY environment variable")

def extract_video_id(url):
    """Extract video ID from YouTube URL"""
    if not url:
        return None
        
    # Handle escaped unicode format (\u003d)
    if 'u003d' in url:
        return url.split('u003d')[-1]
    # Handle standard format (v=)
    elif 'v=' in url:
        return url.split('v=')[-1].split('&')[0]
    # Handle /watch/ format
    elif '/watch/' in url:
        return url.split('/watch/')[-1]
    return None

def get_video_details_batch(video_ids, api_key, batch_size=50):
    """Get details for multiple videos in one API call"""
    url = "https://www.googleapis.com/youtube/v3/videos"
    
    # Convert video_ids to list if it's not already
    video_ids = list(video_ids)
    results = {}
    
    # Process in batches of batch_size
    for i in range(0, len(video_ids), batch_size):
        batch = video_ids[i:i + batch_size]
        
        params = {
            "part": "contentDetails,topicDetails,snippet",
            "id": ",".join(batch),  # Join IDs with commas
            "key": api_key
        }
        
        try:
            response = requests.get(url, params=params)
            response.raise_for_status()
            data = response.json()
            
            # Process each video in the response
            for item in data.get('items', []):
                video_id = item['id']
                
                # Get duration
                duration_iso = item['contentDetails']['duration']
                duration_seconds = int(isodate.parse_duration(duration_iso).total_seconds())
                
                # Get topics
                topic_details = item.get('topicDetails', {})
                categories = [cat.split('/')[-1].replace('_', ' ') 
                            for cat in topic_details.get('topicCategories', [])]
                
                results[video_id] = {
                    'duration_seconds': duration_seconds,
                    'topic_categories': categories
                }
            
            # Add a small delay between batches
            time.sleep(0.1)
            
        except Exception as e:
            print(f"Error processing batch: {str(e)}")
            continue
            
    return results

def enrich_youtube_history(json_file, api_key):
    # First parse the basic history
    df = parse_youtube_history(json_file)
    
    # Extract video IDs from title_url
    df['video_id'] = df['title_url'].apply(extract_video_id)
    
    # Get unique, non-null video IDs
    video_ids = df['video_id'].dropna().unique()
    
    print(f"Processing {len(video_ids)} unique videos...")
    
    # Get details for all videos
    video_details = get_video_details_batch(video_ids, api_key)
    
    # Add the details back to the dataframe
    df['duration_seconds'] = df['video_id'].map(
        lambda x: video_details.get(x, {}).get('duration_seconds'))
    df['topic_categories'] = df['video_id'].map(
        lambda x: video_details.get(x, {}).get('topic_categories'))
    
    return df

# Usage example
if __name__ == "__main__":
    import time
    from tqdm import tqdm
    
    file_path = '/Users/karthiknadella/Documents/Data Stories/youtube/data/raw/watch-history.json'
  
    
    try:
        df = enrich_youtube_history(file_path, api_key)
        
        # Display some statistics
        print("\nData Summary:")
        print(f"Total videos processed: {len(df)}")
        print(f"Videos with duration data: {df['duration_seconds'].notna().sum()}")
        print(f"Videos with topic data: {df['topic_categories'].notna().sum()}")
        
        # Save enriched data
        df.to_csv('/Users/karthiknadella/Documents/Data Stories/youtube/data/processed/enriched_youtube_history.csv', index=False)
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Processing 5706 unique videos...
# Error processing batch: 400 Client Error: Bad Request for url: https://www.googleapis.com/youtube/v3/videos?part=contentDetails%2CtopicDetails%2Csnippet&id=O7DRGCq5f0s%2C_3WPTcVmems%2CmZAPQAZzeH0%2CNdVuu6m3HuM%2CYLXHBIG06-o%2CiM3Voc5XVJk%2COZkduI2JB4k%2CS22DVYC_WDc%2CPdWzqVyrgIs%2CEM8n72-JQsI%2CfcetJAvGaFs%2Cnsh6dZ6449Y%2CfYfun9cFTEg%2Cjoc4vzrL6oU%2CzbvBOooeMqE%2C6lMdT_2egqs%2Ce3FxdFfjmHc%2C7rE2uKXoddQ%2CJrxnqy3X_Rc%2CNZduDPLlCRE%2C3Pls3wJOjXI%2CKjgIuzp61us%2C_XkCZ3ppTag%2C8GD-bX6f_RQ%2CrbX43YK_D6w%2CQ8fiPJ-tbNs%2CHZNdtW1PxKs%2CtnRuOFDDSMM%2Ca4570TxfI8o%2CLvIsyB5gRr0%2CkhQg4o99boI%2CXns33rmcx10%2CLhC-h20L4CE%2COuwOB9BS_3Y%2CRSSi_mXjNSA%2CE4m7B0VlL9w%2CRPh4kRG6Zdg%2CiSYBZCguZRg%2CxL4wjWV3M7I%2Cqn2DjHRk_SA%2Cz4qLpGb1h4Q%2C4s6pV0dxHbM%2C1IdblomQ1Ag%2CR8VbzIqTOCc%2CB1T9VFE7boY%2CkXYiU_JCYtU%2CeVTXPUF4Oz4%2CiAP9AF6DCu4%2C4zbVIsL8OOY%2Cr0U0AlLVqpk&key=AIzaSyDDPgPRjr8tS4S5YYNBRPz4PspZP7xj8HA
# Error processing batch: 400 Client Error: Bad Request for url: https://www.googleapis.com/youtube/v3/videos?part=contentDetails%2CtopicDetails%2Csnippet&id=0DZ5a74HWV4%2CRSfTMl7iJho%2C4I6hGjFtxsk%2CE-wTB7OWG8s%2CQGm5FJmthBc%2C_lCkeh04DRg%2CLlA5a_2yhbQ%2CxM43ls2xaKU%2CdC63D5s_xtY%2CM_Q4J38DKTM%2CyNCCPWOxf0Y%2C2-QJ4qLkF0A%2Cw37X3ft8ZVc%2ClVLasJFOI6M%2CkSLYSdMs6_o%2C2vz3sb4e4Dw%2CX1L38znxEo4%2CFgMjPviGs-s%2CnMavKCcuZoU%2C5msX4wlIJUg%2Cy5PCgSqcLTU%2ClLdRJSoGdH8%2CLo7_hF2OH2U%2CRRUxXtuGR-4%2CjUy3TKjZ2u4%2CHLY7UZnSt_Y%2CD8ET8dwE4cE%2CciHR68BcA3k%2CPAYqro_V-Xg%2CH2x1jFwn3o4%2CZSs6gMLNX2Q%2CqqcbVfHR4Ko%2CbKM2LzwUgco%2CaijFXQlHpWE%2CbDk9tugoWco%2ChT0lRJB-0kE%2Csg7EQV_rxpU%2CrniYjUoNbOU%2CYGj-sbD2Sw4%2CLESg07OBuck%2CjIic9_ZhyC8%2ChlpR_9eVPLo%2CbF014EUJrSI%2CrdzKbICr1A0%2CAwFaK7NbvX8%2C9UF4z56l2VQ%2CSwe1Jl_rEPE%2CLt3GBVyvoBY%2Cw_6NWe4wzto%2ChdRm2eclzu8&key=AIzaSyDDPgPRjr8tS4S5YYNBRPz4PspZP7xj8HA
# Error processing batch: 400 Client Error: Bad Request for url: https://www.googleapis.com/youtube/v3/videos?part=contentDetails%2CtopicDetails%2Csnippet&id=RRL1Wk3aG3k%2CwA5kHe3VKRc%2CfMCdZL856Tc%2CodLE6OIMYU0%2Cns2sDANw-bY%2Cp7AZuf0PBXo%2C1G-6FHg0vQw%2CxFXQbdRJpcU%2CYKKnsEGb4oA%2CGVbHXZz8fNk%2C22cgnDI4Dj4%2CFfAG-0buFgQ%2CKxD14yAK5gA%2CxpwLxtAbVnU%2Cp7VwcRZxp08%2CE-fMh8XXc34%2CGvrBjo-s3FQ%2CPjt3QJ6TgV8%2CFqu8JihsXkM%2Cap82zIPdNUs%2CUgRtYy2X5oI%2Clk0yu7pkdEw%2CaF9GWKTyM6A%2C5J3maPufY6c%2CRDho5Fw6fog%2CNsbS9fqsciE%2ChzJgsItNdN4%2CjMHTSIO7or4%2CSXrWOycyXEs%2CVOaPwe6d0W8%2CAO5EWTs6GyQ%2CEPSQd_uuVSI%2CGIQtyCUB2Tk%2CTCnH9K3p_mY%2CJO7svjK1lig%2CTfX9708gLpA%2CVE_v1dGSdf8%2CrvOCqGdWERM%2CWQ24-_CgfCE%2CWeBq2F38BFk%2CGiZXl2FJwwk%2C42CyvrbcRBI%2Cdmx0zLXqiRI%2CHUPxALemJCY%2CTGWZ13gxTxc%2CwYJFt07euV0%2COJZSc9yo3_0%2CA38zO9XhM3w%2C2fLTV_eOeA8%2CfQz77eeOK-4&key=AIzaSyDDPgPRjr8tS4S5YYNBRPz4PspZP7xj8HA
# Error processing batch: 400 Client Error: Bad Request for url: https://www.googleapis.com/youtube/v3/videos?part=contentDetails%2CtopicDetails%2Csnippet&id=jaVCenKQulM%2C-tMImWDmj3E%2CqIFD-5mVuBE%2C94cBRg8IVkE%2CpA8zhNUwZfY%2CDfNoejo2kGE%2CX_EixhFRZHU%2CoAGMCPIygKI%2COUcjqBLzHX8%2CNaOevKsAfFY%2C3FOLirtmvUA%2CBTDdT4whpRQ%2C8frsrOm8sQs%2CTiWgGfjJJGc%2Cgskfw5orZjU%2CYB34Sc8Cl1c%2CcPvbw7-rwfQ%2Cy_6u0tkIV3Y%2CMxNLDPQoaCk%2CEWsEnt2-XNY%2C7b4VC2Zb7l8%2Co5vxjw1tmqU%2CdcyfM9SjJ-0%2CnqbjpkCbFA8%2CQ1jpVawGFqY%2Cdt3r6wTrbps%2Cfl8OpMYSzKI%2Cw-FOmswuP0I%2CmZ-VrxwtVVo%2CJtvaLwW54P8%2CqVvDyhetcpM%2CIPwfGXSTORE%2C-4Mbma5nSgU%2CJWHrffRZxh4%2CZOR7i7pVpj8%2CoJc1YItRxKk%2CB-qeto6Jv6Q%2CIqcdsIWjrrQ%2CPB-OVIQcLaQ%2CLViBkQjBxTo%2COFDCm33FnwU%2CXqiRPREOj0o%2CfCSoVgvilI0%2CAyZfSdOy3pU%2CE66onUZJ0jQ%2CnglSH9lrvIM%2CkcexF6zT-U4%2CWDb3KIovq3g%2Cjm3dy-NS388%2Ct72kT7h08EA&key=AIzaSyDDPgPRjr8tS4S5YYNBRPz4PspZP7xj8HA
#
# Data Summary:
# Total videos processed: 5867
# Videos with duration data: 5567
# Videos with topic data: 5567

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import ast

# Read the CSV file
df = pd.read_csv('/Users/karthiknadella/Documents/Data Stories/youtube/data/processed/enriched_youtube_history.csv')

# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Basic info about the dataset
print("Dataset Overview:")
print(f"Total records: {len(df)}")
print(f"Date range: {df['timestamp'].min()} to {df['timestamp'].max()}")
print(f"\nColumns in dataset:")
print(df.info())

# Quick statistics about video durations
print("\nVideo Duration Statistics (in minutes):")
print(df['duration_seconds'].describe() / 60)

# Most common topics
print("\nMost Common Topics:")
# Explode the topic_categories list into separate rows
topic_counts = df.explode('topic_categories')['topic_categories'].value_counts().head(10)
print(topic_counts)
# Out:
# Dataset Overview:
# Total records: 5867
# Date range: 2024-04-07 03:20:58.113000+00:00 to 2024-11-17 21:43:04.210000+00:00
#
# Columns in dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5867 entries, 0 to 5866
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   header             5867 non-null   object
#  1   title              5867 non-null   object
#  2   title_url          5867 non-null   object
#  3   channel_name       5781 non-null   object
#  4   channel_url        5781 non-null   object
#  5   timestamp          5867 non-null   datetime64[ns, UTC]
#  6   products           5867 non-null   object
#  7   activity_controls  5867 non-null   object
#  8   video_id           5867 non-null   object
#  9   duration_seconds   5567 non-null   float64
#  10  topic_categories   5567 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), object(9)
# memory usage: 504.3+ KB
# None
#
# Video Duration Statistics (in minutes):
# count      92.783333
# mean        5.760532
# std        48.041877
# min         0.083333
# 25%         0.400000
# 50%         0.833333
# 75%         1.816667
# max      2989.933333
# Name: duration_seconds, dtype: float64
#
# Most Common Topics:
# ['Basketball', 'Sport']              534
# ['Entertainment']                    397
# ['Baseball', 'Sport']                234
# ['Lifestyle (sociology)']            228
# []                                   205
# ['Motorsport', 'Sport']              185
# ['Entertainment', 'Film']            175
# ['Association football', 'Sport']    174
# ['American football', 'Sport']       171
# ['Society']                          155
# Name: topic_categories, dtype: int64

# %%
# Prepare the data
# Read the CSV file
df = pd.read_csv('/Users/karthiknadella/Documents/Data Stories/youtube/data/processed/enriched_youtube_history.csv')

# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Convert timestamp to month and duration to hours
df['month'] = df['timestamp'].dt.to_period('M')
df['duration_hours'] = df['duration_seconds'] / 3600

# Group by month and category, sum the duration
monthly_by_category = df.pivot_table(
    index='month',
    columns='topic_categories',
    values='duration_hours',
    aggfunc='sum'
).fillna(0)

# Create the stacked bar chart
plt.figure(figsize=(15, 8))
monthly_by_category.plot(kind='bar', stacked=True)

plt.title('Monthly Watch Time by Topic Category')
plt.xlabel('Month')
plt.ylabel('Watch Time (Hours)')
plt.legend(title='Topic Categories', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print total hours per category
print("\nTotal Hours per Category:")
category_totals = df.groupby('topic_categories')['duration_hours'].sum().sort_values(ascending=False)
print(category_totals.round(2))
# Out:
# /Users/karthiknadella/Documents/Data Stories/youtube/venv/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
# /var/folders/d3/4lb_fx_x04d3nvwbz2_6sjlm0000gn/T/ipykernel_58807/479400359.py:28: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Total Hours per Category:
# topic_categories
# []                                                              80.62
# ['Health', 'Lifestyle (sociology)', 'Physical fitness']         40.00
# ['Politics', 'Society']                                         38.04
# ['Basketball', 'Sport']                                         37.52
# ['Politics', 'Society', 'Television program']                   33.42
#                                                                 ...
# ['Basketball', 'Sport', 'Volleyball']                            0.00
# ['Lifestyle (sociology)', 'Music of Asia']                       0.00
# ['Baseball', 'Humour', 'Sport']                                  0.00
# ['Hobby', 'Lifestyle (sociology)', 'Music of Latin America']     0.00
# ['Baseball', 'Lifestyle (sociology)']                            0.00
# Name: duration_hours, Length: 345, dtype: float64

# %%
# Convert timestamp to month and duration to hours
df['month'] = df['timestamp'].dt.to_period('M')
df['duration_hours'] = df['duration_seconds'] / 3600

# Extract first category
def get_first_category(categories_str):
    try:
        # Convert string to list using literal_eval and get first item
        categories = ast.literal_eval(categories_str)
        return categories[0] if categories else 'Uncategorized'
    except:
        return 'Uncategorized'

# Create new column with just the first category
df['main_category'] = df['topic_categories'].apply(get_first_category)

# Create the stacked bar chart
plt.figure(figsize=(15, 8))
monthly_by_category = df.pivot_table(
    index='month',
    columns='main_category',
    values='duration_hours',
    aggfunc='sum'
).fillna(0)

monthly_by_category.plot(kind='bar', stacked=True)
plt.title('Monthly Watch Time by Topic Category')
plt.xlabel('Month')
plt.ylabel('Watch Time (Hours)')
plt.legend(title='Topic Categories', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print total hours per category
print("\nTotal Hours per Category:")
category_totals = df.groupby('main_category')['duration_hours'].sum().sort_values(ascending=False)
print(category_totals.round(2))
# Out:
# /Users/karthiknadella/Documents/Data Stories/youtube/venv/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
# /var/folders/d3/4lb_fx_x04d3nvwbz2_6sjlm0000gn/T/ipykernel_58807/3515032353.py:32: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Total Hours per Category:
# main_category
# Uncategorized             80.62
# Politics                  71.46
# Basketball                55.43
# Entertainment             52.54
# Lifestyle (sociology)     46.02
# Health                    42.01
# Society                   27.06
# Motorsport                26.21
# American football         23.34
# Cricket                   14.28
# Hobby                     12.93
# Baseball                  12.92
# Jazz                      11.95
# Sport                     11.79
# Association football       9.96
# Knowledge                  9.04
# Food                       7.18
# Music                      4.23
# Golf                       3.84
# Technology                 1.68
# Video game culture         1.51
# Vehicle                    1.11
# Electronic music           1.10
# Independent music          0.97
# Film                       0.94
# Ice hockey                 0.74
# Action-adventure game      0.71
# Hip hop music              0.59
# Humour                     0.48
# Business                   0.37
# Fashion                    0.35
# Physical fitness           0.23
# Tourism                    0.22
# Racing video game          0.21
# Country music              0.07
# Military                   0.07
# Pet                        0.06
# Religion                   0.05
# Television program         0.04
# Boxing                     0.04
# Mixed martial arts         0.03
# Christian music            0.03
# Sports game                0.03
# Pop music                  0.02
# Professional wrestling     0.02
# Name: duration_hours, dtype: float64

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Convert timestamp to datetime (not Period)
df['month'] = df['timestamp'].dt.strftime('%Y-%m')  # This will be string format 'YYYY-MM'
df['duration_hours'] = df['duration_seconds'] / 3600

# Extract first category
def get_category_at_level(categories_str, level=0):
    try:
        categories = ast.literal_eval(categories_str)
        return categories[level] if len(categories) > level else 'Uncategorized'
    except:
        return 'Uncategorized'

# Create columns for different category levels
df['category_l1'] = df['topic_categories'].apply(lambda x: get_category_at_level(x, 0))
df['category_l2'] = df['topic_categories'].apply(lambda x: get_category_at_level(x, 1))

# Create the interactive visualization
fig = px.bar(df, 
             x='month',
             y='duration_hours',
             color='category_l1',
             title='Monthly Watch Time by Category',
             labels={'duration_hours': 'Watch Time (Hours)',
                    'month': 'Month',
                    'category_l1': 'Category'},
             height=600)

# Update layout
fig.update_layout(barmode='stack',
                 xaxis_tickangle=45,
                 showlegend=True,
                 hovermode='x unified')

# Show the plot
fig.show()
